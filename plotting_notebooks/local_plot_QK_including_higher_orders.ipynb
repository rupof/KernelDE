# %%
import sys
sys.path.append("..")

# %%
from data_tools.tools import *
from scipy.integrate import odeint
import seaborn as sns
from matplotlib import pyplot as plt
from DE_Library.diferential_equation_functionals import *

from matplotlib import rc
rc('text', usetex=True)

# %%
results = load_feather_folder_as_pd("../data/results/DE_3_35")
# Out:
# ['../data/results/DE_3_35\\0.feather', '../data/results/DE_3_35\\1.feather', '../data/results/DE_3_35\\10.feather', '../data/results/DE_3_35\\100.feather', '../data/results/DE_3_35\\101.feather', '../data/results/DE_3_35\\102.feather', '../data/results/DE_3_35\\103.feather', '../data/results/DE_3_35\\104.feather', '../data/results/DE_3_35\\105.feather', '../data/results/DE_3_35\\106.feather', '../data/results/DE_3_35\\107.feather', '../data/results/DE_3_35\\11.feather', '../data/results/DE_3_35\\12.feather', '../data/results/DE_3_35\\120.feather', '../data/results/DE_3_35\\121.feather', '../data/results/DE_3_35\\122.feather', '../data/results/DE_3_35\\123.feather', '../data/results/DE_3_35\\124.feather', '../data/results/DE_3_35\\125.feather', '../data/results/DE_3_35\\126.feather', '../data/results/DE_3_35\\127.feather', '../data/results/DE_3_35\\128.feather', '../data/results/DE_3_35\\129.feather', '../data/results/DE_3_35\\13.feather', '../data/results/DE_3_35\\130.feather', '../data/results/DE_3_35\\131.feather', '../data/results/DE_3_35\\132.feather', '../data/results/DE_3_35\\133.feather', '../data/results/DE_3_35\\134.feather', '../data/results/DE_3_35\\135.feather', '../data/results/DE_3_35\\136.feather', '../data/results/DE_3_35\\137.feather', '../data/results/DE_3_35\\138.feather', '../data/results/DE_3_35\\139.feather', '../data/results/DE_3_35\\14.feather', '../data/results/DE_3_35\\140.feather', '../data/results/DE_3_35\\141.feather', '../data/results/DE_3_35\\142.feather', '../data/results/DE_3_35\\143.feather', '../data/results/DE_3_35\\144.feather', '../data/results/DE_3_35\\145.feather', '../data/results/DE_3_35\\146.feather', '../data/results/DE_3_35\\147.feather', '../data/results/DE_3_35\\148.feather', '../data/results/DE_3_35\\149.feather', '../data/results/DE_3_35\\15.feather', '../data/results/DE_3_35\\150.feather', '../data/results/DE_3_35\\151.feather', '../data/results/DE_3_35\\152.feather', '../data/results/DE_3_35\\153.feather', '../data/results/DE_3_35\\154.feather', '../data/results/DE_3_35\\155.feather', '../data/results/DE_3_35\\156.feather', '../data/results/DE_3_35\\157.feather', '../data/results/DE_3_35\\158.feather', '../data/results/DE_3_35\\159.feather', '../data/results/DE_3_35\\16.feather', '../data/results/DE_3_35\\160.feather', '../data/results/DE_3_35\\161.feather', '../data/results/DE_3_35\\162.feather', '../data/results/DE_3_35\\163.feather', '../data/results/DE_3_35\\164.feather', '../data/results/DE_3_35\\165.feather', '../data/results/DE_3_35\\166.feather', '../data/results/DE_3_35\\167.feather', '../data/results/DE_3_35\\168.feather', '../data/results/DE_3_35\\169.feather', '../data/results/DE_3_35\\17.feather', '../data/results/DE_3_35\\170.feather', '../data/results/DE_3_35\\171.feather', '../data/results/DE_3_35\\172.feather', '../data/results/DE_3_35\\173.feather', '../data/results/DE_3_35\\174.feather', '../data/results/DE_3_35\\175.feather', '../data/results/DE_3_35\\176.feather', '../data/results/DE_3_35\\177.feather', '../data/results/DE_3_35\\178.feather', '../data/results/DE_3_35\\179.feather', '../data/results/DE_3_35\\18.feather', '../data/results/DE_3_35\\180.feather', '../data/results/DE_3_35\\181.feather', '../data/results/DE_3_35\\182.feather', '../data/results/DE_3_35\\183.feather', '../data/results/DE_3_35\\184.feather', '../data/results/DE_3_35\\185.feather', '../data/results/DE_3_35\\186.feather', '../data/results/DE_3_35\\187.feather', '../data/results/DE_3_35\\188.feather', '../data/results/DE_3_35\\189.feather', '../data/results/DE_3_35\\19.feather', '../data/results/DE_3_35\\190.feather', '../data/results/DE_3_35\\191.feather', '../data/results/DE_3_35\\192.feather', '../data/results/DE_3_35\\193.feather', '../data/results/DE_3_35\\194.feather', '../data/results/DE_3_35\\195.feather', '../data/results/DE_3_35\\196.feather', '../data/results/DE_3_35\\197.feather', '../data/results/DE_3_35\\198.feather', '../data/results/DE_3_35\\199.feather', '../data/resu ...
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# ...
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# 1.9782161712646484
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)
# c:\Users\jsl-rf\Desktop\KernelsDE\plotting_notebooks\..\data_tools\tools.py:40: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dict_loss = pd.read_csv(temp_file[:-8]+".log", delim_whitespace=True)

# %%
#include an extra column called epochs, which generates and array from 0 to the number of epochs

results["epochs"] = results["loss_history"].apply(lambda x: np.arange(len(x)))


results["loss_history_cp"] = results["loss_history"]


results["mse_history_cp"] = results["mse_history"]

# %%
results["Number of qubits"] = results["num_qubits"]
results["Iteration"] = results["epochs"]

# %%
#results_QK_exploded["loss_history"] change name to results_QK_exploded["$\mathcal{L}(f^\prime(x), f(x), x)$"]
loss_history_str = "$\mathcal{L}(f^\prime(x), f(x), x)$"
mse_history_str = r"$|f(x)-f_{\mathrm{exact}}(x)|^2$"


results[loss_history_str] = results["loss_history"]
results[mse_history_str] = results["mse_history"]

results["Number of qubits"] = results["num_qubits"]
results["Iteration"] = results["epochs"]

# %%
#results with method = QNN
results_Kernels = results[results["method"] != "QNN"]


#min mse_history_str apply and get the last elemetn of the list
results_Kernels["min " + mse_history_str] = results_Kernels.apply(lambda x: x[mse_history_str][-1], axis=1)
results_Kernels["min " + loss_history_str] = results_Kernels.apply(lambda x: x[loss_history_str][-1], axis=1)



filtering_columns_Kernel = ["method", "loss_name", "Number of qubits", "num_layers", "min " + mse_history_str, "eta"]
mse_df_Kernels = results_Kernels[["method", "loss_name", "Number of qubits", "num_layers", "min " + mse_history_str, "f_sol", "domain", "loss_history_cp", "mse_history_cp", "eta"]].drop_duplicates(subset=filtering_columns_Kernel).rename(columns={"min " + mse_history_str: "min_loss"})
mse_df_Kernels["Type of Loss"] = mse_history_str

filtering_columns_Kernel = ["method", "loss_name", "Number of qubits", "num_layers", "min " + loss_history_str, "eta"]
true_loss_df_Kernels = results_Kernels[["method", "loss_name", "Number of qubits", "num_layers", "min " + loss_history_str, "f_sol", "domain", "loss_history_cp", "mse_history_cp", "eta"]].drop_duplicates(subset=filtering_columns_Kernel).rename(columns={"min " + loss_history_str: "min_loss"})
true_loss_df_Kernels["Type of Loss"] = loss_history_str




combined_df = pd.concat([mse_df_Kernels, true_loss_df_Kernels])
#rename min_loss to Loss

#round upto 3 digits each eta
combined_df["eta"] = combined_df["eta"].apply(lambda x: round(x, 3))

combined_df = combined_df.rename(columns={"min_loss": "Loss"})
combined_df = combined_df.rename(columns={"method": "Method"})
combined_df = combined_df.rename(columns={"Number of qubits": "Qubits"})
combined_df = combined_df.rename(columns={"loss_name": "DE:"})
combined_df = combined_df.rename(columns={"num_layers": "Layers"})

# %%
combined_df
# Out:
#     Method    DE: Qubits Layers          Loss  \
# 0      PQK  paper      2      1  4.018339e-06
# 1      PQK  paper      2      1  3.224971e-06
# 2      FQK  paper      2      1  1.071635e-01
# 3      PQK  paper      8      1  3.754745e-02
# 4      PQK  paper      8      1  3.755128e-02
# ..     ...    ...    ...    ...           ...
# 690    FQK  paper      7      1  1.186119e-03
# 691    PQK  paper      8      1  6.774840e-11
# 692    PQK  paper      8      1  1.124363e-11
# 693    PQK  paper      8      1  4.008535e-11
# 694    PQK  paper      8      1  1.625178e-10
#
#                                                  f_sol  \
# 0    [1.000196801393039, 0.766616163314283, 0.29066...
# 1    [1.0002757045139545, 0.7656300963406912, 0.288...
# 2    [1.0021293124102115, 0.6454754570058796, 0.372...
# 3    [1.0000252770957527, 0.7357965229537484, 0.288...
# 4    [1.0000678828445373, 0.7358342002919149, 0.288...
# ..                                                 ...
# 690  [0.9999792005051855, 0.7649601376357227, 0.285...
# 691  [0.9999976070812219, 0.7357727875946438, 0.288...
# 692  [1.0000011642322861, 0.7357751912169664, 0.288...
# 693  [1.0000034787488286, 0.7357772536309166, 0.288...
# 694  [1.0000096120791049, 0.7357826515672563, 0.288...
#
#                                                 domain  \
# 0    [0.0, 0.03103448275862069, 0.06206896551724138...
# 1    [0.0, 0.03103448275862069, 0.06206896551724138...
# 2    [0.0, 0.03103448275862069, 0.06206896551724138...
# 3    [0.0, 0.03103448275862069, 0.06206896551724138...
# 4    [0.0, 0.03103448275862069, 0.06206896551724138...
# ..                                                 ...
# 690  [0.0, 0.03103448275862069, 0.06206896551724138...
# 691  [0.0, 0.03103448275862069, 0.06206896551724138...
# 692  [0.0, 0.03103448275862069, 0.06206896551724138...
# 693  [0.0, 0.03103448275862069, 0.06206896551724138...
# 694  [0.0, 0.03103448275862069, 0.06206896551724138...
#
#                                        loss_history_cp  \
# 0    [209.71699113977064, 176.34087722358376, 132.1...
# 1    [511.1384688004289, 431.90460422728665, 373.20...
# 2    [2608.1857554429084, 2306.104371656356, 2245.9...
# 3    [914.5963773466594, 645.5836077624529, 522.367...
# 4    [2450.624065349693, 1732.4959689509164, 1403.9...
# ..                                                 ...
# 690  [69476.98352408774, 50994.884439055546, 46285....
# 691  [18.971329339691444, 12.202780070776077, 10.53...
# 692  [48.87604127406627, 33.03199535316974, 26.4383...
# 693  [128.54199763297484, 89.3602651164787, 71.5379...
# 694  [342.01385026174256, 240.41514734870063, 193.8...
#
#                                         mse_history_cp     eta  \
# 0    [74.5563123465402, 53.78883126655306, 30.79250...   0.010
# 1    [75.7543412380789, 53.21411726553514, 25.32291...   0.027
# 2    [203.63252724089185, 100.4119932744648, 94.103...   0.072
# 3    [5.200650994059227, 2.838924007459819, 0.51180...   0.518
# 4    [5.2071884789171605, 2.8572959063960117, 0.524...   1.389
# ..                                                 ...     ...
# 690  [27.89439954450056, 2.21620002576582, 1.401544...  10.000
# 691  [4.710570131095082, 1.907299575901832, 0.15731...   0.010
# 692  [5.0146400445998704, 2.3770920500506634, 0.258...   0.027
# 693  [5.136626803001593, 2.6662127697925073, 0.4003...   0.072
# 694  [5.183163975320272, 2.790431663720403, 0.47852...   0.193
#
#                             Type of Loss
# 0       $|f(x)-f_{\mathrm{exact}}(x)|^2$
# 1       $|f(x)-f_{\mathrm{exact}}(x)|^2$
# 2       $|f(x)-f_{\mathrm{exact}}(x)|^2$
# 3       $|f(x)-f_{\mathrm{exact}}(x)|^2$
# 4       $|f(x)-f_{\mathrm{exact}}(x)|^2$
# ..                                   ...
# 690  $\mathcal{L}(f^\prime(x), f(x), x)$
# 691  $\mathcal{L}(f^\prime(x), f(x), x)$
# 692  $\mathcal{L}(f^\prime(x), f(x), x)$
# 693  $\mathcal{L}(f^\prime(x), f(x), x)$
# 694  $\mathcal{L}(f^\prime(x), f(x), x)$
#
# [1390 rows x 11 columns]

# %%
combined_df
# Out:
#     Method    DE: Qubits Layers          Loss  \
# 0      PQK  paper      2      1  4.018339e-06
# 1      PQK  paper      2      1  3.224971e-06
# 2      FQK  paper      2      1  1.071635e-01
# 3      PQK  paper      8      1  3.754745e-02
# 4      PQK  paper      8      1  3.755128e-02
# ..     ...    ...    ...    ...           ...
# 690    FQK  paper      7      1  1.186119e-03
# 691    PQK  paper      8      1  6.774840e-11
# 692    PQK  paper      8      1  1.124363e-11
# 693    PQK  paper      8      1  4.008535e-11
# 694    PQK  paper      8      1  1.625178e-10
#
#                                                  f_sol  \
# 0    [1.000196801393039, 0.766616163314283, 0.29066...
# 1    [1.0002757045139545, 0.7656300963406912, 0.288...
# 2    [1.0021293124102115, 0.6454754570058796, 0.372...
# 3    [1.0000252770957527, 0.7357965229537484, 0.288...
# 4    [1.0000678828445373, 0.7358342002919149, 0.288...
# ..                                                 ...
# 690  [0.9999792005051855, 0.7649601376357227, 0.285...
# 691  [0.9999976070812219, 0.7357727875946438, 0.288...
# 692  [1.0000011642322861, 0.7357751912169664, 0.288...
# 693  [1.0000034787488286, 0.7357772536309166, 0.288...
# 694  [1.0000096120791049, 0.7357826515672563, 0.288...
#
#                                                 domain  \
# 0    [0.0, 0.03103448275862069, 0.06206896551724138...
# 1    [0.0, 0.03103448275862069, 0.06206896551724138...
# 2    [0.0, 0.03103448275862069, 0.06206896551724138...
# 3    [0.0, 0.03103448275862069, 0.06206896551724138...
# 4    [0.0, 0.03103448275862069, 0.06206896551724138...
# ..                                                 ...
# 690  [0.0, 0.03103448275862069, 0.06206896551724138...
# 691  [0.0, 0.03103448275862069, 0.06206896551724138...
# 692  [0.0, 0.03103448275862069, 0.06206896551724138...
# 693  [0.0, 0.03103448275862069, 0.06206896551724138...
# 694  [0.0, 0.03103448275862069, 0.06206896551724138...
#
#                                        loss_history_cp  \
# 0    [209.71699113977064, 176.34087722358376, 132.1...
# 1    [511.1384688004289, 431.90460422728665, 373.20...
# 2    [2608.1857554429084, 2306.104371656356, 2245.9...
# 3    [914.5963773466594, 645.5836077624529, 522.367...
# 4    [2450.624065349693, 1732.4959689509164, 1403.9...
# ..                                                 ...
# 690  [69476.98352408774, 50994.884439055546, 46285....
# 691  [18.971329339691444, 12.202780070776077, 10.53...
# 692  [48.87604127406627, 33.03199535316974, 26.4383...
# 693  [128.54199763297484, 89.3602651164787, 71.5379...
# 694  [342.01385026174256, 240.41514734870063, 193.8...
#
#                                         mse_history_cp     eta  \
# 0    [74.5563123465402, 53.78883126655306, 30.79250...   0.010
# 1    [75.7543412380789, 53.21411726553514, 25.32291...   0.027
# 2    [203.63252724089185, 100.4119932744648, 94.103...   0.072
# 3    [5.200650994059227, 2.838924007459819, 0.51180...   0.518
# 4    [5.2071884789171605, 2.8572959063960117, 0.524...   1.389
# ..                                                 ...     ...
# 690  [27.89439954450056, 2.21620002576582, 1.401544...  10.000
# 691  [4.710570131095082, 1.907299575901832, 0.15731...   0.010
# 692  [5.0146400445998704, 2.3770920500506634, 0.258...   0.027
# 693  [5.136626803001593, 2.6662127697925073, 0.4003...   0.072
# 694  [5.183163975320272, 2.790431663720403, 0.47852...   0.193
#
#                             Type of Loss
# 0       $|f(x)-f_{\mathrm{exact}}(x)|^2$
# 1       $|f(x)-f_{\mathrm{exact}}(x)|^2$
# 2       $|f(x)-f_{\mathrm{exact}}(x)|^2$
# 3       $|f(x)-f_{\mathrm{exact}}(x)|^2$
# 4       $|f(x)-f_{\mathrm{exact}}(x)|^2$
# ..                                   ...
# 690  $\mathcal{L}(f^\prime(x), f(x), x)$
# 691  $\mathcal{L}(f^\prime(x), f(x), x)$
# 692  $\mathcal{L}(f^\prime(x), f(x), x)$
# 693  $\mathcal{L}(f^\prime(x), f(x), x)$
# 694  $\mathcal{L}(f^\prime(x), f(x), x)$
#
# [1390 rows x 11 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

latex_odes = {
    "log_ode": r"df/dx - e^{-f(x)} = 0",
    "polynomial_with_exp": r"2f(x) + 4 \cos(x) - 8 \sin(x) - df/dx = 0",
    "paper_decay_QNN": r"df/dx + 8f(x)  (0.1 + \tan(8x)) = 0",
    "simple_test_QNN": r"df/dx + \sin(x) = 0",
    "paper_nontrivial_dynamics": r"df/dx -4f(x) + 6f^2 - \sin(50x)-f(x)\cos(25x) + 0.5", 
    "logistic_equation": r"f(x)(10 - f(x))-df/dx=0",
    "paper": r"df/dx + 20 e^{-2 x} \sin(20 x) + 2 f(x) = 0"
}
ode_names = ["simple_test_QNN", "paper", "paper_nontrivial_dynamics", "paper_decay_QNN", "polynomial_with_exp", "logistic_equation", "log_ode"]

plt.figure(figsize=(10, 10))
ax = plt.gca()

# Add a box around the text
rect = patches.FancyBboxPatch((0.05, 0.05), 0.9, 0.9, boxstyle="round,pad=0.05", edgecolor='black', facecolor='lightgrey', alpha=0.5)
ax.add_patch(rect)

for i, ode_name in enumerate(ode_names):
    try:
        text_str = f"{ode_name}: ${latex_odes[ode_name]}$"
        plt.text(0.5, 0.6 - i * 0.04, text_str, fontsize=15, ha='center', va='top', wrap=True)
    except:
        pass

# Remove axis
plt.axis('off')

plt.show()

# %%
#make a relplot, showing the smallest value of the loss function for each method and loss function as a funtion of the number of qubits
sns.set_context("paper", rc={"font.size":14,"axes.titlesize":16,"axes.labelsize":16, 
                             "legend.fontsize":14, "xtick.labelsize":16, 
                             "ytick.labelsize":16, "legend.title_fontsize":14,  'lines.linewidth': 3})

palette = sns.color_palette("colorblind")
#create array with best 
best_mse_loss = combined_df
best_mse_loss = best_mse_loss[best_mse_loss["Type of Loss"] == mse_history_str]
#sort by mse loss
best_mse_loss.sort_values("Loss", inplace=True)
best_mse_loss.drop_duplicates(subset=["Method", "DE:", "Qubits", "Layers", "eta"], inplace=True)

best_loss_loss = combined_df
best_loss_loss = best_loss_loss[best_loss_loss["Type of Loss"] == loss_history_str]
best_loss_loss.sort_values("Loss", inplace=True)
best_loss_loss.drop_duplicates(subset=["Method", "DE:", "Qubits", "Layers", "eta"], inplace=True)


g = sns.relplot(x="Qubits", y="Loss",
                data=best_mse_loss,
                kind="line", 
                col="Method", 
                col_order=["FQK", "PQK", "QNN"],
                hue="eta",
                style="Type of Loss",
                row="DE:",
                row_order=ode_names,
                height=2.5,  # Adjust the height as needed
                aspect=2,  
                marker="o",
                palette=palette
                )

#g log scale
#g title

#plt.suptitle 

g.set_titles("{col_name} / {row_name}")
g.set(yscale="log")


#leg = g._legend

plt.ylim(1e-12, 1e2)


#leg.set_frame_on(True)

#export with 400 dpi
#plt.savefig("./DE_0_30_comparison.png", dpi=400)
# Out:
# C:\Users\jsl-rf\AppData\Local\Temp\ipykernel_22980\1192101268.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_mse_loss.sort_values("Loss", inplace=True)
# C:\Users\jsl-rf\AppData\Local\Temp\ipykernel_22980\1192101268.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_mse_loss.drop_duplicates(subset=["Method", "DE:", "Qubits", "Layers", "eta"], inplace=True)
# C:\Users\jsl-rf\AppData\Local\Temp\ipykernel_22980\1192101268.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_loss_loss.sort_values("Loss", inplace=True)
# C:\Users\jsl-rf\AppData\Local\Temp\ipykernel_22980\1192101268.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_loss_loss.drop_duplicates(subset=["Method", "DE:", "Qubits", "Layers", "eta"], inplace=True)
# C:\Users\jsl-rf\AppData\Local\Temp\ipykernel_22980\1192101268.py:20: UserWarning: The palette list has more values (10) than needed (8), which may not be intended.
#   g = sns.relplot(x="Qubits", y="Loss",
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# (1e-12, 100.0)

# %%
#make a relplot, showing the smallest value of the loss function for each method and loss function as a funtion of the number of qubits
sns.set_context("paper", rc={"font.size":14,"axes.titlesize":16,"axes.labelsize":16, 
                             "legend.fontsize":14, "xtick.labelsize":16, 
                             "ytick.labelsize":16, "legend.title_fontsize":14,  'lines.linewidth': 3})

palette = sns.color_palette("colorblind")
#create array with best 
best_mse_loss = combined_df
best_mse_loss = best_mse_loss[best_mse_loss["Type of Loss"] == mse_history_str]
#sort by mse loss
best_mse_loss.sort_values("Loss", inplace=True)
best_mse_loss.drop_duplicates(subset=["Method", "DE:", "Qubits", "Layers", "eta"], inplace=True)

best_loss_loss = combined_df
best_loss_loss = best_loss_loss[best_loss_loss["Type of Loss"] == loss_history_str]
best_loss_loss.sort_values("Loss", inplace=True)
best_loss_loss.drop_duplicates(subset=["Method", "DE:", "Qubits", "Layers", "eta"], inplace=True)


g = sns.relplot(x="Qubits", y="Loss",
                data=best_loss_loss,
                kind="line", 
                col="Method", 
                col_order=["FQK", "PQK", "QNN"],
                hue="eta",
                style="Type of Loss",
                row="DE:",
                row_order=ode_names,
                height=2.5,  # Adjust the height as needed
                aspect=2,  
                marker="o",
                palette=palette
                )

#g log scale
#g title

#plt.suptitle 

g.set_titles("{col_name} / {row_name}")
g.set(yscale="log")


#leg = g._legend

plt.ylim(1e-12, 1e2)


#leg.set_frame_on(True)

#export with 400 dpi
#plt.savefig("./DE_0_30_comparison.png", dpi=400)
# Out:
# C:\Users\jsl-rf\AppData\Local\Temp\ipykernel_22980\67881035.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_mse_loss.sort_values("Loss", inplace=True)
# C:\Users\jsl-rf\AppData\Local\Temp\ipykernel_22980\67881035.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_mse_loss.drop_duplicates(subset=["Method", "DE:", "Qubits", "Layers", "eta"], inplace=True)
# C:\Users\jsl-rf\AppData\Local\Temp\ipykernel_22980\67881035.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_loss_loss.sort_values("Loss", inplace=True)
# C:\Users\jsl-rf\AppData\Local\Temp\ipykernel_22980\67881035.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_loss_loss.drop_duplicates(subset=["Method", "DE:", "Qubits", "Layers", "eta"], inplace=True)
# C:\Users\jsl-rf\AppData\Local\Temp\ipykernel_22980\67881035.py:20: UserWarning: The palette list has more values (10) than needed (8), which may not be intended.
#   g = sns.relplot(x="Qubits", y="Loss",
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\jsl-rf\AppData\Roaming\Python\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# (1e-12, 100.0)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Set the context for the plots
sns.set_context("paper", rc={"font.size":14,"axes.titlesize":16,"axes.labelsize":16, 
                             "legend.fontsize":14, "xtick.labelsize":16, 
                             "ytick.labelsize":16, "legend.title_fontsize":14,  'lines.linewidth': 3})

# Assuming combined_df is already defined and contains the relevant data
# Filter data for the MSE loss


#create array with best 
best_mse_loss = combined_df
best_mse_loss = best_mse_loss[best_mse_loss["Type of Loss"] == mse_history_str]
#sort by mse loss
best_mse_loss.sort_values("Loss", inplace=True)
best_mse_loss = best_mse_loss.fillna("Unnecessary")

best_mse_loss.drop_duplicates(subset=["Method", "DE:", "Qubits"], inplace=True)

best_loss_loss = combined_df
best_loss_loss = best_loss_loss[best_loss_loss["Type of Loss"] == loss_history_str]
best_loss_loss.sort_values("Loss", inplace=True)
best_loss_loss.drop_duplicates(subset=["Method", "DE:", "Qubits"], inplace=True)

best_mse_loss["MSE Loss"] = best_mse_loss["Loss"]

# Filter for FQK and PQK methods
best_mse_fqk = best_mse_loss[best_mse_loss["Method"] == "FQK"]
best_mse_pqk = best_mse_loss[best_mse_loss["Method"] == "PQK"]

# Pivot the data to create matrices for the heatmaps
fqk_matrix = best_mse_fqk.pivot(index="DE:", columns="Qubits", values="MSE Loss")
pqk_matrix = best_mse_pqk.pivot(index="DE:", columns="Qubits", values="MSE Loss")

fqk_matrix = fqk_matrix.reindex(ode_names, axis=0)
pqk_matrix = pqk_matrix.reindex(ode_names, axis=0)
# Out:
# C:\Users\jsl-rf\AppData\Local\Temp\ipykernel_22980\1108522982.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_mse_loss.sort_values("Loss", inplace=True)
# C:\Users\jsl-rf\AppData\Local\Temp\ipykernel_22980\1108522982.py:19: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   best_mse_loss = best_mse_loss.fillna("Unnecessary")
# C:\Users\jsl-rf\AppData\Local\Temp\ipykernel_22980\1108522982.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_loss_loss.sort_values("Loss", inplace=True)
# C:\Users\jsl-rf\AppData\Local\Temp\ipykernel_22980\1108522982.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_loss_loss.drop_duplicates(subset=["Method", "DE:", "Qubits"], inplace=True)

# %%
# sns.heatmap log scale

from matplotlib.colors import LogNorm
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 2, figsize=(20, 10))

vmin = min(fqk_matrix.min().min(), pqk_matrix.min().min())
vmax = min(max(fqk_matrix.max().max(), pqk_matrix.max().max()), 10)
shared_norm = LogNorm(vmin=vmin, vmax=vmax)
sns.heatmap(fqk_matrix, ax=ax[0], cmap="viridis", cbar_kws={'label': 'MSE Loss'}, annot_kws={"size": 12}, norm=shared_norm)
sns.heatmap(pqk_matrix, ax=ax[1], cmap="viridis", cbar_kws={'label': 'MSE Loss'}, annot_kws={"size": 12}, norm=shared_norm)


#log colorbar




plt.tight_layout()

# %%
#make a relplot, showing the smallest value of the loss function for each method and loss function as a funtion of the number of qubits
sns.set_context("paper", rc={"font.size":14,"axes.titlesize":16,"axes.labelsize":16, 
                             "legend.fontsize":14, "xtick.labelsize":16, 
                             "ytick.labelsize":16, "legend.title_fontsize":14,  'lines.linewidth': 3})

#create array with best 
best_mse_loss = combined_df
best_mse_loss = best_mse_loss[best_mse_loss["Type of Loss"] == mse_history_str]
#sort by mse loss
best_mse_loss.sort_values("Loss", inplace=True)
best_mse_loss = best_mse_loss.fillna("Unnecessary")

best_mse_loss.drop_duplicates(subset=["Method", "DE:"], inplace=True)

best_loss_loss = combined_df
best_loss_loss = best_loss_loss[best_loss_loss["Type of Loss"] == loss_history_str]
best_loss_loss.sort_values("Loss", inplace=True)
best_loss_loss.drop_duplicates(subset=["Method", "DE:"], inplace=True)

#best_mse_loss["MSE Loss"] = best_mse_loss["Loss"]

#sort y by ode_names
#best_mse_loss["DE:"] = pd.Categorical(best_mse_loss["DE:"], categories=ode_names, ordered=True)

g = sns.relplot(y="DE:", x="Loss",
                data=best_mse_loss,
                kind="scatter", 
                hue="Method",
                hue_order=["FQK", "PQK", "QNN"],
                height=3,  # Adjust the height as needed
                aspect=3,  
                palette=palette,
                s=100
                )

#g log scale
#g title

#plt.suptitle 

g.set_titles("{col_name} / {row_name}")
g.set(xscale="log")


#leg = g._legend

plt.xlim(1e-12, 1e6)


#create a box of text outside of the plot with the latex ode dictionary
# Create a text box with the ODEs

plt

#leg.set_frame_on(True)

#export with 400 dpi
#plt.savefig("./DE_0_30_comparison.png", dpi=400)
# Out:
# C:\Users\jsl-rf\AppData\Local\Temp\ipykernel_22980\3637721710.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_mse_loss.sort_values("Loss", inplace=True)
# C:\Users\jsl-rf\AppData\Local\Temp\ipykernel_22980\3637721710.py:11: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   best_mse_loss = best_mse_loss.fillna("Unnecessary")
# C:\Users\jsl-rf\AppData\Local\Temp\ipykernel_22980\3637721710.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_loss_loss.sort_values("Loss", inplace=True)
# C:\Users\jsl-rf\AppData\Local\Temp\ipykernel_22980\3637721710.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_loss_loss.drop_duplicates(subset=["Method", "DE:"], inplace=True)
# C:\Users\jsl-rf\AppData\Local\Temp\ipykernel_22980\3637721710.py:25: UserWarning: The palette list has more values (10) than needed (3), which may not be intended.
#   g = sns.relplot(y="DE:", x="Loss",
# <module 'matplotlib.pyplot' from 'C:\\Users\\jsl-rf\\AppData\\Roaming\\Python\\Python310\\site-packages\\matplotlib\\pyplot.py'>

# %%
#make a relplot, showing the smallest value of the loss function for each method and loss function as a funtion of the number of qubits
sns.set_context("paper", rc={"font.size":14,"axes.titlesize":16,"axes.labelsize":16, 
                             "legend.fontsize":14, "xtick.labelsize":16, 
                             "ytick.labelsize":16, "legend.title_fontsize":14,  'lines.linewidth': 3})

#create array with best 
best_mse_loss = combined_df
best_mse_loss = best_mse_loss[best_mse_loss["Type of Loss"] == mse_history_str]
#sort by mse loss
best_mse_loss.sort_values("Loss", inplace=True)
best_mse_loss = best_mse_loss.fillna("Unnecessary")

best_mse_loss.drop_duplicates(subset=["Method", "DE:"], inplace=True)

best_loss_loss = combined_df
best_loss_loss = best_loss_loss[best_loss_loss["Type of Loss"] == loss_history_str]
best_loss_loss.sort_values("Loss", inplace=True)
best_loss_loss.drop_duplicates(subset=["Method", "DE:"], inplace=True)

#best_mse_loss["MSE Loss"] = best_mse_loss["Loss"]

#sort y by ode_names
#best_mse_loss["DE:"] = pd.Categorical(best_mse_loss["DE:"], categories=ode_names, ordered=True)

g = sns.relplot(y="DE:", x="Loss",
                data=best_loss_loss,
                kind="scatter", 
                hue="Method",
                hue_order=["FQK", "PQK", "QNN"],
                height=3,  # Adjust the height as needed
                aspect=3,  
                palette=palette,
                s=100
                )

#g log scale
#g title

#plt.suptitle 

g.set_titles("{col_name} / {row_name}")
g.set(xscale="log")


#leg = g._legend

plt.xlim(1e-12, 1e6)


#create a box of text outside of the plot with the latex ode dictionary
# Create a text box with the ODEs

plt

#leg.set_frame_on(True)

#export with 400 dpi
#plt.savefig("./DE_0_30_comparison.png", dpi=400)
# Out:
# C:\Users\jsl-rf\AppData\Local\Temp\ipykernel_22980\2696579587.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_mse_loss.sort_values("Loss", inplace=True)
# C:\Users\jsl-rf\AppData\Local\Temp\ipykernel_22980\2696579587.py:11: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   best_mse_loss = best_mse_loss.fillna("Unnecessary")
# C:\Users\jsl-rf\AppData\Local\Temp\ipykernel_22980\2696579587.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_loss_loss.sort_values("Loss", inplace=True)
# C:\Users\jsl-rf\AppData\Local\Temp\ipykernel_22980\2696579587.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_loss_loss.drop_duplicates(subset=["Method", "DE:"], inplace=True)
# C:\Users\jsl-rf\AppData\Local\Temp\ipykernel_22980\2696579587.py:25: UserWarning: The palette list has more values (10) than needed (3), which may not be intended.
#   g = sns.relplot(y="DE:", x="Loss",
# <module 'matplotlib.pyplot' from 'C:\\Users\\jsl-rf\\AppData\\Roaming\\Python\\Python310\\site-packages\\matplotlib\\pyplot.py'>

# %%
#make a relplot, showing the smallest value of the loss function for each method and loss function as a funtion of the number of qubits
sns.set_context("paper", rc={"font.size":14,"axes.titlesize":16,"axes.labelsize":16, 
                             "legend.fontsize":14, "xtick.labelsize":16, 
                             "ytick.labelsize":16, "legend.title_fontsize":14,  'lines.linewidth': 3})

#create array with best 
best_mse_loss = combined_df
best_mse_loss = best_mse_loss[best_mse_loss["Type of Loss"] == mse_history_str]
#sort by mse loss
best_mse_loss.sort_values("Loss", inplace=True)
best_mse_loss = best_mse_loss.fillna("Unnecessary")

best_mse_loss.drop_duplicates(subset=["Method", "DE:"], inplace=True)

best_loss_loss = combined_df
best_loss_loss = best_loss_loss[best_loss_loss["Type of Loss"] == loss_history_str]
best_loss_loss.sort_values("Loss", inplace=True)
best_loss_loss.drop_duplicates(subset=["Method", "DE:"], inplace=True)

#create a column best_loss_loss["DE:"] = with the ode names latex in 
#best_loss_loss["DE:"] = pd.Categorical(best_mse_loss["DE:"], categories=ode_names, ordered=True)
best_loss_loss["Differential Equation"] = best_loss_loss["DE:"].apply(lambda x: f"${latex_odes[x]}$")

#best_mse_loss["MSE Loss"] = best_mse_loss["Loss"]

#sort y by ode_names
#best_mse_loss["DE:"] = pd.Categorical(best_mse_loss["DE:"], categories=ode_names, ordered=True)

g = sns.relplot(y="Differential Equation", x="Loss",
                data=best_loss_loss,
                kind="scatter", 
                hue="Method",
                hue_order=["FQK", "PQK"],
                height=3,  # Adjust the height as needed
                aspect=4,  
                palette=palette,
                s=100
                )

#g log scale
#g title

#plt.suptitle 

g.set_titles("{col_name} / {row_name}")
g.set(xscale="log")


#leg = g._legend

plt.xlim(1e-12, 1e6)


#create a box of text outside of the plot with the latex ode dictionary
# Create a text box with the ODEs

plt

#leg.set_frame_on(True)

#export with 400 dpi
#plt.savefig("./DE_0_30_comparison.png", dpi=400)
# Out:
# C:\Users\jsl-rf\AppData\Local\Temp\ipykernel_22980\4113201484.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_mse_loss.sort_values("Loss", inplace=True)
# C:\Users\jsl-rf\AppData\Local\Temp\ipykernel_22980\4113201484.py:11: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   best_mse_loss = best_mse_loss.fillna("Unnecessary")
# C:\Users\jsl-rf\AppData\Local\Temp\ipykernel_22980\4113201484.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_loss_loss.sort_values("Loss", inplace=True)
# C:\Users\jsl-rf\AppData\Local\Temp\ipykernel_22980\4113201484.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_loss_loss.drop_duplicates(subset=["Method", "DE:"], inplace=True)
# C:\Users\jsl-rf\AppData\Local\Temp\ipykernel_22980\4113201484.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_loss_loss["Differential Equation"] = best_loss_loss["DE:"].apply(lambda x: f"${latex_odes[x]}$")
# C:\Users\jsl-rf\AppData\Local\Temp\ipykernel_22980\4113201484.py:29: UserWarning: The palette list has more values (10) than needed (2), which may not be intended.
#   g = sns.relplot(y="Differential Equation", x="Loss",
# <module 'matplotlib.pyplot' from 'C:\\Users\\jsl-rf\\AppData\\Roaming\\Python\\Python310\\site-packages\\matplotlib\\pyplot.py'>

# %%
true_solution_continous_dictionary = {
                    "paper": odeint(mapping_of_derivatives_of_loss_functions["paper"], 1, np.linspace(0, 0.9, 30)),  
                    "log_ode": odeint(mapping_of_derivatives_of_loss_functions["log_ode"], np.log(0.01), np.linspace(0, 0.9, 30)), 
                    "polynomial_with_exp": odeint(mapping_of_derivatives_of_loss_functions["polynomial_with_exp"], 3, np.linspace(0, 0.9, 30)),
                    "paper_decay_QNN": odeint(mapping_of_derivatives_of_loss_functions["paper_decay_QNN"], 1, np.linspace(0, 0.9, 30)),
                    "simple_test_QNN": odeint(mapping_of_derivatives_of_loss_functions["simple_test_QNN"], 1, np.linspace(0, 0.9, 300)),
                    "paper_nontrivial_dynamics": odeint(mapping_of_derivatives_of_loss_functions["paper_nontrivial_dynamics"], 0.75, np.linspace(0, 0.9, 30)),
                    "logistic_equation": odeint(mapping_of_derivatives_of_loss_functions["logistic_equation"], 0.1, np.linspace(0, 0.9, 30))}

# %%
true_solution_continous_dictionary["paper"].T
# Out:
# array([[ 1.        ,  0.76452088,  0.2857264 , -0.23838158, -0.61686556,
#         -0.73266079, -0.57541752, -0.23270894,  0.15242042,  0.43859922,
#          0.53600997,  0.43218538,  0.18739441, -0.09519732, -0.3110783 ,
#         -0.39156793, -0.32396135, -0.14949495,  0.05755744,  0.22005033,
#          0.28562807,  0.24237608,  0.11831989, -0.03316455, -0.15521697,
#         -0.20804036, -0.18100576, -0.09301202,  0.01765554,  0.10914969]])

# %%
true_solution_continous_dictionary["simple_test_QNN"].T[0]
# Out:
# array([1.        , 0.99994566, 0.99978269, 0.99951129, 0.99913182,
#        0.99864478, 0.99805074, 0.99735055, 0.99654512, 0.99563547,
#        0.99462281, 0.99350844, 0.99229382, 0.99098054, 0.98957033,
#        0.98806501, 0.98646655, 0.98477703, 0.98299866, 0.98113376,
#        0.97918475, 0.97715419, 0.97504472, 0.97285909, 0.97060016,
#        0.96827088, 0.96587427, 0.96341347, 0.96089169, 0.95831221,
#        0.9556784 , 0.95299371, 0.95026162, 0.9474857 , 0.94466959,
#        0.94181694, 0.93893148, 0.93601697, 0.93307723, 0.93011607,
#        0.92713737, 0.92414501, 0.9211429 , 0.91813494, 0.91512507,
#        0.91211721, 0.90911529, 0.90612322, 0.90314491, 0.90018423,
#        0.89724506, 0.89433122, 0.89144652, 0.88859472, 0.88577954,
#        0.88300465, 0.88027368, 0.87759019, 0.87495767, 0.87237956,
#        0.86985923, 0.86739996, 0.86500496, 0.86267736, 0.86042018,
#        0.85823639, 0.85612882, 0.85410022, 0.85215324, 0.85029042,
#        0.8485142 , 0.84682688, 0.84523067, 0.84372766, 0.84231979,
#        0.84100892, 0.83979674, 0.83868485, 0.83767468, 0.83676756,
#        0.83596467, 0.83526706, 0.83467564, 0.83419118, 0.83381431,
#        0.83354553, 0.83338518, 0.83333348, 0.83339048, 0.83355613,
#        0.8338302 , 0.83421233, 0.83470203, 0.83529865, 0.83600143,
#        0.83680943, 0.83772161, 0.83873678, 0.83985361, 0.84107065,
#        0.8423863 , 0.84379886, 0.84530648, 0.84690718, 0.8485989 ,
#        0.85037941, 0.85224639, 0.85419742, 0.85622994, 0.8583413 ,
#        0.86052874, 0.86278943, 0.86512039, 0.86751861, 0.86998094,
#        0.87250417, 0.87508501, 0.8777201 , 0.88040599, 0.8831392 ,
#        0.88591613, 0.88873319, 0.89158668, 0.89447289, 0.89738805,
#        0.90032837, 0.90328999, 0.90626907, 0.90926172, 0.91226402,
#        0.91527207, 0.91828194, 0.92128971, 0.92429144, 0.92728322,
#        0.93026115, 0.93322135, 0.93615996, 0.93907313, 0.94195708,
#        0.94480803, 0.94762227, 0.95039612, 0.95312598, 0.95580827,
#        0.95843951, 0.96101624, 0.96353513, 0.96599287, 0.96838626,
#        0.97071218, 0.9729676 , 0.97514957, 0.97725524, 0.97928188,
#        0.98122683, 0.98308756, 0.98486165, 0.98654676, 0.98814072,
#        0.98964144, 0.99104696, 0.99235545, 0.99356519, 0.99467462,
#        0.99568229, 0.99658688, 0.99738721, 0.99808223, 0.99867105,
#        0.99915288, 0.99952711, 0.99979325, 0.99995094, 0.99999999,
#        0.99994032, 0.99977203, 0.99949531, 0.99911054, 0.99861823,
#        0.998019  , 0.99731364, 0.99650308, 0.99558837, 0.9945707 ,
#        0.99345141, 0.99223194, 0.9909139 , 0.98949899, 0.98798908,
#        0.98638612, 0.98469221, 0.98290956, 0.98104049, 0.97908745,
#        0.97705297, 0.97493972, 0.97275045, 0.97048801, 0.96815536,
#        0.96575555, 0.96329169, 0.96076701, 0.9581848 , 0.95554843,
#        0.95286133, 0.95012702, 0.94734906, 0.94453107, 0.94167673,
#        0.93878977, 0.93587394, 0.93293305, 0.92997095, 0.92699149,
#        0.92399856, 0.92099606, 0.91798792, 0.91497806, 0.9119704 ,
#        0.90896886, 0.90597737, 0.90299982, 0.90004009, 0.89710206,
#        0.89418955, 0.89130637, 0.88845628, 0.88564298, 0.88287016,
#        0.88014143, 0.87746034, 0.87483041, 0.87225504, 0.86973762,
#        0.86728141, 0.86488963, 0.86256539, 0.86031173, 0.85813159,
#        0.8560278 , 0.85400313, 0.85206021, 0.85020156, 0.84842963,
#        0.84674671, 0.84515501, 0.84365659, 0.84225342, 0.84094733,
#        0.83974001, 0.83863305, 0.83762789, 0.83672583, 0.83592806,
#        0.83523562, 0.83464941, 0.83417019, 0.8337986 , 0.83353511,
#        0.83338007, 0.83333367, 0.83339599, 0.83356694, 0.8338463 ,
#        0.8342337 , 0.83472864, 0.83533047, 0.83603841, 0.83685152,
#        0.83776876, 0.83878893, 0.83991069, 0.84113259, 0.84245302,
#        0.84387026, 0.84538247, 0.84698768, 0.84868378, 0.85046857,
#        0.85233972, 0.85429479, 0.85633122, 0.85844636, 0.86063746,
#        0.86290164, 0.86523597, 0.86763739, 0.87010276, 0.87262889,
#        0.87521246, 0.87785011, 0.8805384 , 0.88327383, 0.88605281,
#        0.88887173, 0.89172691, 0.89461463, 0.89753111, 0.90047256])

# %%
plt.plot(np.gradient(true_solution_continous_dictionary["paper"].T[0], np.linspace(0, 0.9, 30) ))
plt.plot(true_solution_continous_dictionary["paper"].T[0])

# dfdx = []
# for i in range(len(true_solution_continous_dictionary["paper"])):
#     if i == 299:
#         break
#     dfdx.append(*(true_solution_continous_dictionary["paper"][i+1] -   true_solution_continous_dictionary["paper"][i])/0.0030100334448160534 )
# plt.plot(dfdx, "--")

# %%
plt.plot(np.gradient(true_solution_continous_dictionary["paper"].T[0]))
plt.plot(true_solution_continous_dictionary["paper"])

# %%
#create array with best 
best_mse_loss = combined_df
best_mse_loss = best_mse_loss[best_mse_loss["Type of Loss"] == mse_history_str]
##sort by mse loss
best_mse_loss.sort_values("Loss", inplace=True)
best_mse_loss.drop_duplicates(subset=["Method", "DE:",], inplace=True)
best_mse_loss.sort_values("Method", inplace=True)


# function_list = [("paper", [1], np.linspace(0, 0.9, 30)), 
#                  ("log_ode", [np.log(0.01)], np.linspace(0.01, 0.9, 30)),
#                  ("polynomial_with_exp", [3], np.linspace(0, 0.9, 30)),
#                  ("paper_decay_QNN", [1], np.linspace(0, 0.9, 30)),
#                 ("simple_test_QNN", [1], np.linspace(0, 0.9, 30)),
#                 ("paper_nontrivial_dynamics", [0.75], np.linspace(0, 0.9, 30)),
#                 ("logistic_equation", [0.1], np.linspace(0, 0.9, 30)),
true_sol = odeint(mapping_of_derivatives_of_loss_functions["paper"], 1, best_mse_loss["domain"].iloc[0])
true_sol_continous = odeint(mapping_of_derivatives_of_loss_functions["paper"], 1, np.linspace(0, 1, 100))

true_solution_dictionary = {
                    "paper": odeint(mapping_of_derivatives_of_loss_functions["paper"], 1, np.linspace(0, 0.9, 30)),  
                    "log_ode": odeint(mapping_of_derivatives_of_loss_functions["log_ode"], np.log(0.01), best_mse_loss["domain"].iloc[0]), 
                    "polynomial_with_exp": odeint(mapping_of_derivatives_of_loss_functions["polynomial_with_exp"], 3, np.linspace(0, 0.9, 30)),
                    "paper_decay_QNN": odeint(mapping_of_derivatives_of_loss_functions["paper_decay_QNN"], 1, np.linspace(0, 0.9, 30)),
                    "simple_test_QNN": odeint(mapping_of_derivatives_of_loss_functions["simple_test_QNN"], 1, np.linspace(0, 0.9, 30)),
                    "paper_nontrivial_dynamics": odeint(mapping_of_derivatives_of_loss_functions["paper_nontrivial_dynamics"], 0.75, np.linspace(0, 0.9, 30)),
                    "logistic_equation": odeint(mapping_of_derivatives_of_loss_functions["logistic_equation"], 0.1, np.linspace(0, 0.9, 30))}

                              


#let us plot the predictions of the best method 

fig, axs = plt.subplots(2, len(best_mse_loss["DE:"].unique()) , figsize=(20, 12))

for j, de_name in enumerate(ode_names):
    axs[0, j].plot(best_mse_loss["domain"].iloc[0], true_solution_dictionary[de_name], "x", label="f(x)", c="red")
    for m, method in enumerate(["FQK", "PQK"]):
        df = best_mse_loss[(best_mse_loss["Method"] == method) & (best_mse_loss["DE:"] == de_name)]
        axs[0, j].plot(df["domain"].iloc[0], df["f_sol"].iloc[0], label=method, c=palette[m])
        #axs[0, j].set_title(f"${latex_odes[de_name]}$", fontsize=8)
        axs[0, j].set_xlabel("$x$")

        axs[1, j].plot(df["mse_history_cp"].iloc[0],  c=palette[m], linestyle="-")
        axs[1, j].plot(df["loss_history_cp"].iloc[0], c=palette[m], linestyle="--")

        axs[1, j].set_yscale("log")
        axs[1, j].set_xlabel("Iteration")

        if j == 0:
            axs[0, j].set_ylabel("f(x)")
            axs[1, j].set_ylabel("Loss")

#dummy plot to include label and then remove -, label: MSE Loss
axs[1,0].plot([0.1],[0.1], linestyle="-", label=r"MSE$(f_{exact}, f_{trial})$", c="black")
axs[1,0].plot([1],[1], linestyle="--", label=r"$\mathcal{L}( df_{trial}/dx, f_{trial}, x)$", c="black")



axs[1,0].legend()     
axs[0,0].legend()
plt.suptitle("Best solvers of the DEs")
plt.tight_layout()
# Out:
# C:\Users\jsl-rf\AppData\Local\Temp\ipykernel_22980\294745448.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_mse_loss.sort_values("Loss", inplace=True)
# C:\Users\jsl-rf\AppData\Local\Temp\ipykernel_22980\294745448.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_mse_loss.drop_duplicates(subset=["Method", "DE:",], inplace=True)
# C:\Users\jsl-rf\AppData\Local\Temp\ipykernel_22980\294745448.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_mse_loss.sort_values("Method", inplace=True)
