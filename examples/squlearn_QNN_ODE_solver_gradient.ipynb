# %%
import sys
sys.path.append("..")

# %%
from squlearn.observables import SummedPaulis
from squlearn.qnn import QNNRegressor
from squlearn.qnn.lowlevel_qnn import LowLevelQNN
from squlearn.optimizers import Adam
from squlearn.qnn.loss import ODELoss
from squlearn.qnn.training import *
from squlearn.encoding_circuit import *
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
from circuits.circuits import SimpleAnalyticalCircuit

# %%
def loss_eq(f_alpha_tensor):
    """
    Args:
        f_array (np.array): array of shape (n, 4) where n is the number of points, each entry corresponds to 
    x, f, dfdx and dfdxdx. This is: f_array = [x, f, dfdx, dfdxdx]
    Returns:
    loss (np.array): array of shape [F] where F is the loss function
    """
    x, f, dfdx = f_alpha_tensor
    return dfdx + f - np.cos(x)

def grad_eq(f_alpha_tensor):
    """
    Args:
        f_array (np.array): array of shape (n, 4) where n is the number of points, each entry corresponds to 
    x, f, dfdx and dfdxdx. This is: f_array = [x, f, dfdx, dfdxdx]
    Returns:
    grad (np.array): array of shape [F, 4] where F is the loss function and 4 is the number of parameters
    """
    x, f, dfdx = f_alpha_tensor
    return np.array([1, 1, 0])

# %%
x_line = np.linspace(-0.9, 0.9, 15) #x domain to solve the ODE
x_line = np.array([0.1, 0.2, 0.3, 0.4])
f_initial = [np.cos(x_line[0])] #Initial condition for the ODE

# %%
num_qubits = 2
num_features = 1
num_layers = 1
circuit = SimpleAnalyticalCircuit(num_qubits, num_features, num_layers)
#circuit = ChebyshevPQC(num_qubits, num_features, num_layers)
#circuit = HEE
executor = Executor("pennylane")

Observables = SummedPaulis(num_qubits, include_identity=False)                                                      
param_obs = Observables.generate_initial_parameters(seed=1)
param_ini = circuit.generate_initial_parameters(seed=1)

adam = Adam(options={"maxiter": 200, "tol": 0.00009, "log_file": "SHO_DE.log", "skip_mse_fun":False, "lr":0.02})
#loss_harmonic_oscillator, grad_loss_harmonic_oscillator

# %%
loss_ODE_np = ODELoss(loss_eq, grad_eq, initial_vec = f_initial, eta=1, boundary_handling = "pinned")

# %%
x = sp.symbols('x')
f, dfdx, dfdxdx = sp.symbols("f dfdx dfdxdx")
k = 1
eq = -sp.cos(x) + f + dfdx

# %%
y = sp.Function('y')

# %%
x = sp.symbols('x')
f, dfdx, dfdxdx = sp.symbols("f dfdx dfdxdx")
k = 1
eq = -sp.cos(x) + sp.exp(f) + dfdx

loss_ODE_sp = ODELoss(eq, initial_vec = f_initial, eta=1, boundary_handling = "pinned", symbols_involved_in_ODE = [x, f, dfdx])

# %%
loss_ODE = loss_ODE_sp
ode_regressor = QNNRegressor(
    circuit,
    Observables,
    executor,
    loss_ODE,
    adam,
    param_ini,
    param_obs,
    opt_param_op = True, #Parametrized Observables not benchmarked yet
)

# %%
x_line.shape[0]
# Out:
# 4

# %%
np.exp(1.9488048)
# Out:
# 7.020291911444291

# %%
ode_regressor.fit(x_line, np.zeros((x_line.shape[0])),  weights=None)
f_QNN = ode_regressor.predict(x_line)
# Out:
# 164.11886310313264
# (array([0.1, 0.2, 0.3, 0.4]), array([1.91253104, 1.9488048 , 1.97559841, 1.99264417]), array([0.40900746, 0.31586304, 0.21956261, 0.12106839]))
# dF dpartial [array([6.77020277, 7.02029189, 7.21093346, 7.33490286]), 1] dimension_of_gradient_with_respect_to dfdp n_param 1
# n_param 1
# --------------------
# grad_envelope_list [[[6.77020277]
#   [7.02029189]
#   [7.21093346]
#   [7.33490286]]
#
#  [[1.        ]
#   [1.        ]
#   [1.        ]
#   [1.        ]]]
# (array([0.1, 0.2, 0.3, 0.4]), array([1.91253104, 1.9488048 , 1.97559841, 1.99264417]), array([0.40900746, 0.31586304, 0.21956261, 0.12106839]))
# dF dpartial [array([6.77020277, 7.02029189, 7.21093346, 7.33490286]), 1] dimension_of_gradient_with_respect_to dfdop n_param 2
# n_param 2
# --------------------
# grad_envelope_list [[[6.77020277 6.77020277]
#   [7.02029189 7.02029189]
#   [7.21093346 7.21093346]
#   [7.33490286 7.33490286]]
#
#  [[1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]]]
# 149.31161875446446
# (array([0.1, 0.2, 0.3, 0.4]), array([1.86608556, 1.90345224, 1.93159209, 1.95022395]), array([0.41863157, 0.3280792 , 0.23424878, 0.13807782]))
# dF dpartial [array([6.46294797, 6.70901563, 6.90048771, 7.03026184]), 1] dimension_of_gradient_with_respect_to dfdp n_param 1
# n_param 1
# --------------------
# grad_envelope_list [[[6.46294797]
#   [6.70901563]
#   [6.90048771]
#   [7.03026184]]
#
#  [[1.        ]
#   [1.        ]
#   [1.        ]
#   [1.        ]]]
# (array([0.1, 0.2, 0.3, 0.4]), array([1.86608556, 1.90345224, 1.93159209, 1.95022395]), array([0.41863157, 0.3280792 , 0.23424878, 0.13807782]))
# dF dpartial [array([6.46294797, 6.70901563, 6.90048771, 7.03026184]), 1] dimension_of_gradient_with_respect_to dfdop n_param 2
# n_param 2
# --------------------
# grad_envelope_list [[[6.46294797 6.46294797]
#   [6.70901563 6.70901563]
#   [6.90048771 6.90048771]
#   [7.03026184 7.03026184]]
#
#  [[1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]]]
# 131.35828837427445
# (array([0.1, 0.2, 0.3, 0.4]), array([1.80367672, 1.84237796, 1.87219428, 1.89282775]), array([0.43022037, 0.34315947, 0.25266983, 0.15965559]))
# dF dpartial [array([6.07193124, 6.31152902, 6.50254917, 6.63811308]), 1] dimension_of_gradient_with_respect_to dfdp n_param 1
# n_param 1
# --------------------
# grad_envelope_list [[[6.07193124]
#   [6.31152902]
#   [6.50254917]
#   [6.63811308]]
#
#  [[1.        ]
#   [1.        ]
#   [1.        ]
#   [1.        ]]]
# (array([0.1, 0.2, 0.3, 0.4]), array([1.80367672, 1.84237796, 1.87219428, 1.89282775]), array([0.43022037, 0.34315947, 0.25266983, 0.15965559]))
# dF dpartial [array([6.07193124, 6.31152902, 6.50254917, 6.63811308]), 1] dimension_of_gradient_with_respect_to dfdop n_param 2
# n_param 2
# --------------------
# grad_envelope_list [[[6.07193124 6.07193124]
#   [6.31152902 6.31152902]
#   [6.50254917 6.50254917]
#   [6.63811308 6.63811308]]
#
#  [[1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]]]
# 117.52029188712335
# (array([0.1, 0.2, 0.3, 0.4]), array([1.74993275, 1.78966619, 1.82081037, 1.84305412]), array([0.43902695, 0.35497942, 0.26738506, 0.17711908]))
# dF dpartial [array([5.7542157 , 5.98745344, 6.17686196, 6.31579801]), 1] dimension_of_gradient_with_respect_to dfdp n_param 1
# n_param 1
# --------------------
# grad_envelope_list [[[5.7542157 ]
#   [5.98745344]
#   [6.17686196]
#   [6.31579801]]
#
#  [[1.        ]
#   [1.        ]
#   [1.        ]
#   [1.        ]]]
# (array([0.1, 0.2, 0.3, 0.4]), array([1.74993275, 1.78966619, 1.82081037, 1.84305412]), array([0.43902695, 0.35497942, 0.26738506, 0.17711908]))
# dF dpartial [array([5.7542157 , 5.98745344, 6.17686196, 6.31579801]), 1] dimension_of_gradient_with_respect_to dfdop n_param 2
# n_param 2
# --------------------
# grad_envelope_list [[[5.7542157  5.7542157 ]
#   [5.98745344 5.98745344]
#   [6.17686196 6.17686196]
#   [6.31579801 6.31579801]]
#
#  [[1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]]]
# 105.80941535824256
# (array([0.1, 0.2, 0.3, 0.4]), array([1.69967646, 1.74028012, 1.77257194, 1.79622926]), array([0.44631076, 0.36508552, 0.28021247, 0.19253963]))
# dF dpartial [array([5.47217666, 5.69893959, 5.88597225, 6.02687876]), 1] dimension_of_gradient_with_respect_to dfdp n_param 1
# n_param 1
# --------------------
# grad_envelope_list [[[5.47217666]
#   [5.69893959]
#   [5.88597225]
#   [6.02687876]]
#
#  [[1.        ]
#   [1.        ]
#   [1.        ]
#   [1.        ]]]
# (array([0.1, 0.2, 0.3, 0.4]), array([1.69967646, 1.74028012, 1.77257194, 1.79622926]), array([0.44631076, 0.36508552, 0.28021247, 0.19253963]))
# dF dpartial [array([5.47217666, 5.69893959, 5.88597225, 6.02687876]), 1] dimension_of_gradient_with_respect_to dfdop n_param 2
# n_param 2
# --------------------
# grad_envelope_list [[[5.47217666 5.47217666]
#   [5.69893959 5.69893959]
#   [5.88597225 5.88597225]
#   [6.02687876 6.02687876]]
#
#  [[1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]]]
# 95.60439301436645
# (array([0.1, 0.2, 0.3, 0.4]), array([1.65152327, 1.69287616, 1.72618374, 1.7511132 ]), array([0.4524433 , 0.37392525, 0.29167106, 0.20650259]))
# dF dpartial [array([5.2149175 , 5.43509045, 5.61916873, 5.76101227]), 1] dimension_of_gradient_with_respect_to dfdp n_param 1
# n_param 1
# --------------------
# grad_envelope_list [[[5.2149175 ]
#   [5.43509045]
#   [5.61916873]
#   [5.76101227]]
#
#  [[1.        ]
#   [1.        ]
#   [1.        ]
#   [1.        ]]]
# (array([0.1, 0.2, 0.3, 0.4]), array([1.65152327, 1.69287616, 1.72618374, 1.7511132 ]), array([0.4524433 , 0.37392525, 0.29167106, 0.20650259]))
# dF dpartial [array([5.2149175 , 5.43509045, 5.61916873, 5.76101227]), 1] dimension_of_gradient_with_respect_to dfdop n_param 2
# n_param 2
# --------------------
# grad_envelope_list [[[5.2149175  5.2149175 ]
#   [5.43509045 5.43509045]
#   [5.61916873 5.61916873]
#   [5.76101227 5.76101227]]
#
#  [[1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]]]
# 86.5969059950187
# (array([0.1, 0.2, 0.3, 0.4]), array([1.60493635, 1.6469362 , 1.68114916, 1.70723338]), array([0.45759702, 0.3816999 , 0.30198897, 0.21926066]))
# dF dpartial [array([4.97754276, 5.19105109, 5.37172539, 5.51368609]), 1] dimension_of_gradient_with_respect_to dfdp n_param 1
# n_param 1
# --------------------
# grad_envelope_list [[[4.97754276]
#   [5.19105109]
#   [5.37172539]
#   [5.51368609]]
#
#  [[1.        ]
#   [1.        ]
#   [1.        ]
#   [1.        ]]]
# (array([0.1, 0.2, 0.3, 0.4]), array([1.60493635, 1.6469362 , 1.68114916, 1.70723338]), array([0.45759702, 0.3816999 , 0.30198897, 0.21926066]))
# dF dpartial [array([4.97754276, 5.19105109, 5.37172539, 5.51368609]), 1] dimension_of_gradient_with_respect_to dfdop n_param 2
# n_param 2
# --------------------
# grad_envelope_list [[[4.97754276 4.97754276]
#   [5.19105109 5.19105109]
#   [5.37172539 5.37172539]
#   [5.51368609 5.51368609]]
#
#  [[1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]]]
# 78.59346156441511
# (array([0.1, 0.2, 0.3, 0.4]), array([1.55967445, 1.6022299 , 1.63724997, 1.66438475]), array([0.4618748 , 0.38852482, 0.31129283, 0.2309505 ]))
# dF dpartial [array([4.75727224, 4.96408949, 5.1410121 , 5.28242223]), 1] dimension_of_gradient_with_respect_to dfdp n_param 1
# n_param 1
# --------------------
# grad_envelope_list [[[4.75727224]
#   [4.96408949]
#   [5.1410121 ]
#   [5.28242223]]
#
#  [[1.        ]
#   [1.        ]
#   [1.        ]
#   [1.        ]]]
# (array([0.1, 0.2, 0.3, 0.4]), array([1.55967445, 1.6022299 , 1.63724997, 1.66438475]), array([0.4618748 , 0.38852482, 0.31129283, 0.2309505 ]))
# dF dpartial [array([4.75727224, 4.96408949, 5.1410121 , 5.28242223]), 1] dimension_of_gradient_with_respect_to dfdop n_param 2
# n_param 2
# --------------------
# grad_envelope_list [[[4.75727224 4.75727224]
#   [4.96408949 4.96408949]
#   [5.1410121  5.1410121 ]
#   [5.28242223 5.28242223]]
#
#  [[1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]]]
# 71.45476360654504
# (array([0.1, 0.2, 0.3, 0.4]), array([1.5156238 , 1.55865105, 1.59438803, 1.62247766]), array([0.46534955, 0.39447829, 0.31966553, 0.24165879]))
# dF dpartial [array([4.55225994, 4.75240618, 4.92531401, 5.06562567]), 1] dimension_of_gradient_with_respect_to dfdp n_param 1
# n_param 1
# --------------------
# grad_envelope_list [[[4.55225994]
#   [4.75240618]
#   [4.92531401]
#   [5.06562567]]
#
#  [[1.        ]
#   [1.        ]
#   [1.        ]
#   [1.        ]]]
# (array([0.1, 0.2, 0.3, 0.4]), array([1.5156238 , 1.55865105, 1.59438803, 1.62247766]), array([0.46534955, 0.39447829, 0.31966553, 0.24165879]))
# dF dpartial [array([4.55225994, 4.75240618, 4.92531401, 5.06562567]), 1] dimension_of_gradient_with_respect_to dfdop n_param 2
# n_param 2
# --------------------
# grad_envelope_list [[[4.55225994 4.55225994]
#   [4.75240618 4.75240618]
#   [4.92531401 4.92531401]
#   [5.06562567 5.06562567]]
#
#  [[1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]]]
# 65.07184850075915
# (array([0.1, 0.2, 0.3, 0.4]), array([1.47273231, 1.51615352, 1.55252332, 1.5814783 ]), array([0.46807966, 0.39962072, 0.3271689 , 0.25144812]))
# dF dpartial [array([4.36113486, 4.55467201, 4.72337372, 4.8621382 ]), 1] dimension_of_gradient_with_respect_to dfdp n_param 1
# n_param 1
# --------------------
# grad_envelope_list [[[4.36113486]
#   [4.55467201]
#   [4.72337372]
#   [4.8621382 ]]
#
#  [[1.        ]
#   [1.        ]
#   [1.        ]
#   [1.        ]]]
# (array([0.1, 0.2, 0.3, 0.4]), array([1.47273231, 1.51615352, 1.55252332, 1.5814783 ]), array([0.46807966, 0.39962072, 0.3271689 , 0.25144812]))
# dF dpartial [array([4.36113486, 4.55467201, 4.72337372, 4.8621382 ]), 1] dimension_of_gradient_with_respect_to dfdop n_param 2
# n_param 2
# --------------------
# grad_envelope_list [[[4.36113486 4.36113486]
#   [4.55467201 4.55467201]
#   [4.72337372 4.72337372]
#   [4.8621382  4.8621382 ]]
#
#  [[1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]]]
# 59.35504732935684
# (array([0.1, 0.2, 0.3, 0.4]), array([1.43097931, 1.47472174, 1.51164538, 1.5413813 ]), array([0.47011603, 0.40400332, 0.33385395, 0.26036882]))
# dF dpartial [array([4.18279344, 4.36981964, 4.5341851 , 4.67103791]), 1] dimension_of_gradient_with_respect_to dfdp n_param 1
# n_param 1
# --------------------
# grad_envelope_list [[[4.18279344]
#   [4.36981964]
#   [4.5341851 ]
#   [4.67103791]]
#
#  [[1.        ]
#   [1.        ]
#   [1.        ]
#   [1.        ]]]
# (array([0.1, 0.2, 0.3, 0.4]), array([1.43097931, 1.47472174, 1.51164538, 1.5413813 ]), array([0.47011603, 0.40400332, 0.33385395, 0.26036882]))
# dF dpartial [array([4.18279344, 4.36981964, 4.5341851 , 4.67103791]), 1] dimension_of_gradient_with_respect_to dfdop n_param 2
# n_param 2
# --------------------
# grad_envelope_list [[[4.18279344 4.18279344]
#   [4.36981964 4.36981964]
#   [4.5341851  4.5341851 ]
#   [4.67103791 4.67103791]]
#
#  [[1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]]]
# 54.228241236078546
# (array([0.1, 0.2, 0.3, 0.4]), array([1.39036008, 1.43435564, 1.47175874, 1.50219565]), array([0.47150547, 0.40767243, 0.33976606, 0.26846487]))
# dF dpartial [array([4.01629597, 4.1969398 , 4.35689104, 4.49154012]), 1] dimension_of_gradient_with_respect_to dfdp n_param 1
# n_param 1
# --------------------
# grad_envelope_list [[[4.01629597]
#   [4.1969398 ]
#   [4.35689104]
#   [4.49154012]]
#
#  [[1.        ]
#   [1.        ]
#   [1.        ]
#   [1.        ]]]
# (array([0.1, 0.2, 0.3, 0.4]), array([1.39036008, 1.43435564, 1.47175874, 1.50219565]), array([0.47150547, 0.40767243, 0.33976606, 0.26846487]))
# dF dpartial [array([4.01629597, 4.1969398 , 4.35689104, 4.49154012]), 1] dimension_of_gradient_with_respect_to dfdop n_param 2
# n_param 2
# --------------------
# grad_envelope_list [[[4.01629597 4.01629597]
#   [4.1969398  4.1969398 ]
#   [4.35689104 4.35689104]
#   [4.49154012 4.49154012]]
#
#  [[1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]]]
# 49.62557048256959
# (array([0.1, 0.2, 0.3, 0.4]), array([1.35087729, 1.39506233, 1.43287481, 1.46393694]), array([0.47229248, 0.41067171, 0.34494765, 0.27577698]))
# dF dpartial [array([3.86081111, 4.03522608, 4.19072946, 4.32294523]), 1] dimension_of_gradient_with_respect_to dfdp n_param 1
# n_param 1
# --------------------
# grad_envelope_list [[[3.86081111]
#   [4.03522608]
#   [4.19072946]
#   [4.32294523]]
#
#  [[1.        ]
#   [1.        ]
#   [1.        ]
#   [1.        ]]]
# (array([0.1, 0.2, 0.3, 0.4]), array([1.35087729, 1.39506233, 1.43287481, 1.46393694]), array([0.47229248, 0.41067171, 0.34494765, 0.27577698]))
# dF dpartial [array([3.86081111, 4.03522608, 4.19072946, 4.32294523]), 1] dimension_of_gradient_with_respect_to dfdop n_param 2
# n_param 2
# --------------------
# grad_envelope_list [[[3.86081111 3.86081111]
#   [4.03522608 4.03522608]
#   [4.19072946 4.19072946]
#   [4.32294523 4.32294523]]
#
#  [[1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]]]
# 45.489382880002786
# (array([0.1, 0.2, 0.3, 0.4]), array([1.3125361 , 1.35685121, 1.39500716, 1.42662271]), array([0.47252014, 0.41304336, 0.34943959, 0.28234433]))
# dF dpartial [array([3.71558488, 3.88394431, 4.03500347, 4.16461031]), 1] dimension_of_gradient_with_respect_to dfdp n_param 1
# n_param 1
# --------------------
# grad_envelope_list [[[3.71558488]
#   [3.88394431]
#   [4.03500347]
#   [4.16461031]]
#
#  [[1.        ]
#   [1.        ]
#   [1.        ]
#   [1.        ]]]
# (array([0.1, 0.2, 0.3, 0.4]), array([1.3125361 , 1.35685121, 1.39500716, 1.42662271]), array([0.47252014, 0.41304336, 0.34943959, 0.28234433]))
# dF dpartial [array([3.71558488, 3.88394431, 4.03500347, 4.16461031]), 1] dimension_of_gradient_with_respect_to dfdop n_param 2
# n_param 2
# --------------------
# grad_envelope_list [[[3.71558488 3.71558488]
#   [3.88394431 3.88394431]
#   [4.03500347 4.03500347]
#   [4.16461031 4.16461031]]
#
#  [[1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]]]
# 41.76885210239294
# (array([0.1, 0.2, 0.3, 0.4]), array([1.27534117, 1.31973112, 1.35816868, 1.3902698 ]), array([0.47223042, 0.41482859, 0.35328193, 0.28820539]))
# dF dpartial [array([3.57992256, 3.74241497, 3.88906466, 4.01593341]), 1] dimension_of_gradient_with_respect_to dfdp n_param 1
# n_param 1
# --------------------
# grad_envelope_list [[[3.57992256]
#   [3.74241497]
#   [3.88906466]
#   [4.01593341]]
#
#  [[1.        ]
#   [1.        ]
#   [1.        ]
#   [1.        ]]]
# (array([0.1, 0.2, 0.3, 0.4]), array([1.27534117, 1.31973112, 1.35816868, 1.3902698 ]), array([0.47223042, 0.41482859, 0.35328193, 0.28820539]))
# dF dpartial [array([3.57992256, 3.74241497, 3.88906466, 4.01593341]), 1] dimension_of_gradient_with_respect_to dfdop n_param 2
# n_param 2
# --------------------
# grad_envelope_list [[[3.57992256 3.57992256]
#   [3.74241497 3.74241497]
#   [3.88906466 3.88906466]
#   [4.01593341 4.01593341]]
#
#  [[1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]]]
# 38.41897974481282
# (array([0.1, 0.2, 0.3, 0.4]), array([1.23929496, 1.28370859, 1.32236992, 1.35489265]), array([0.47146439, 0.4160679 , 0.35651421, 0.29339834]))
# dF dpartial [array([3.45317798, 3.61000296, 3.75230351, 3.87634483]), 1] dimension_of_gradient_with_respect_to dfdp n_param 1
# n_param 1
# --------------------
# grad_envelope_list [[[3.45317798]
#   [3.61000296]
#   [3.75230351]
#   [3.87634483]]
#
#  [[1.        ]
#   [1.        ]
#   [1.        ]
#   [1.        ]]]
# (array([0.1, 0.2, 0.3, 0.4]), array([1.23929496, 1.28370859, 1.32236992, 1.35489265]), array([0.47146439, 0.4160679 , 0.35651421, 0.29339834]))
# dF dpartial [array([3.45317798, 3.61000296, 3.75230351, 3.87634483]), 1] dimension_of_gradient_with_respect_to dfdop n_param 2
# n_param 2
# --------------------
# grad_envelope_list [[[3.45317798 3.45317798]
#   [3.61000296 3.61000296]
#   [3.75230351 3.75230351]
#   [3.87634483 3.87634483]]
#
#  [[1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]]]
# 35.39982963056021
# (array([0.1, 0.2, 0.3, 0.4]), array([1.20439675, 1.24878691, 1.2876181 , 1.32050235]), array([0.47026211, 0.41680108, 0.35917552, 0.2979612 ]))
# dF dpartial [array([3.33474678, 3.48611141, 3.62414393, 3.74530234]), 1] dimension_of_gradient_with_respect_to dfdp n_param 1
# n_param 1
# --------------------
# grad_envelope_list [[[3.33474678]
#   [3.48611141]
#   [3.62414393]
#   [3.74530234]]
#
#  [[1.        ]
#   [1.        ]
#   [1.        ]
#   [1.        ]]]
# (array([0.1, 0.2, 0.3, 0.4]), array([1.20439675, 1.24878691, 1.2876181 , 1.32050235]), array([0.47026211, 0.41680108, 0.35917552, 0.2979612 ]))
# dF dpartial [array([3.33474678, 3.48611141, 3.62414393, 3.74530234]), 1] dimension_of_gradient_with_respect_to dfdop n_param 2
# n_param 2
# --------------------
# grad_envelope_list [[[3.33474678 3.33474678]
#   [3.48611141 3.48611141]
#   [3.62414393 3.62414393]
#   [3.74530234 3.74530234]]
#
#  [[1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]]]
# 32.675910812336646
# (array([0.1, 0.2, 0.3, 0.4]), array([1.17064214, 1.21496557, 1.25391661, 1.28710608]), array([0.46866254, 0.41706709, 0.36130445, 0.30193178]))
# dF dpartial [array([3.22406228, 3.37017802, 3.50404007, 3.62228877]), 1] dimension_of_gradient_with_respect_to dfdp n_param 1
# n_param 1
# --------------------
# grad_envelope_list [[[3.22406228]
#   [3.37017802]
#   [3.50404007]
#   [3.62228877]]
#
#  [[1.        ]
#   [1.        ]
#   [1.        ]
#   [1.        ]]]
# (array([0.1, 0.2, 0.3, 0.4]), array([1.17064214, 1.21496557, 1.25391661, 1.28710608]), array([0.46866254, 0.41706709, 0.36130445, 0.30193178]))
# dF dpartial [array([3.22406228, 3.37017802, 3.50404007, 3.62228877]), 1] dimension_of_gradient_with_respect_to dfdop n_param 2
# n_param 2
# --------------------
# grad_envelope_list [[[3.22406228 3.22406228]
#   [3.37017802 3.37017802]
#   [3.50404007 3.50404007]
#   [3.62228877 3.62228877]]
#
#  [[1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]]]
# 30.21566160127016
# (array([0.1, 0.2, 0.3, 0.4]), array([1.1380229 , 1.18224012, 1.22126479, 1.25470699]), array([0.46670339, 0.41690393, 0.36293891, 0.30534753]))
# dF dpartial [array([3.12059255, 3.26167257, 3.39147453, 3.50681068]), 1] dimension_of_gradient_with_respect_to dfdp n_param 1
# n_param 1
# --------------------
# grad_envelope_list [[[3.12059255]
#   [3.26167257]
#   [3.39147453]
#   [3.50681068]]
#
#  [[1.        ]
#   [1.        ]
#   [1.        ]
#   [1.        ]]]
# (array([0.1, 0.2, 0.3, 0.4]), array([1.1380229 , 1.18224012, 1.22126479, 1.25470699]), array([0.46670339, 0.41690393, 0.36293891, 0.30534753]))
# dF dpartial [array([3.12059255, 3.26167257, 3.39147453, 3.50681068]), 1] dimension_of_gradient_with_respect_to dfdop n_param 2
# n_param 2
# --------------------
# grad_envelope_list [[[3.12059255 3.12059255]
#   [3.26167257 3.26167257]
#   [3.39147453 3.39147453]
#   [3.50681068 3.50681068]]
#
#  [[1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]]]
# 27.99100657195701
# (array([0.1, 0.2, 0.3, 0.4]), array([1.106527  , 1.1506022 , 1.18965798, 1.22330409]), array([0.46442092, 0.41634845, 0.36411597, 0.30824536]))
# dF dpartial [array([3.02383835, 3.16009536, 3.28595714, 3.3983978 ]), 1] dimension_of_gradient_with_respect_to dfdp n_param 1
# n_param 1
# --------------------
# grad_envelope_list [[[3.02383835]
#   [3.16009536]
#   [3.28595714]
#   [3.3983978 ]]
#
#  [[1.        ]
#   [1.        ]
#   [1.        ]
#   [1.        ]]]
# (array([0.1, 0.2, 0.3, 0.4]), array([1.106527  , 1.1506022 , 1.18965798, 1.22330409]), array([0.46442092, 0.41634845, 0.36411597, 0.30824536]))
# dF dpartial [array([3.02383835, 3.16009536, 3.28595714, 3.3983978 ]), 1] dimension_of_gradient_with_respect_to dfdop n_param 2
# n_param 2
# --------------------
# grad_envelope_list [[[3.02383835 3.02383835]
#   [3.16009536 3.16009536]
#   [3.28595714 3.28595714]
#   [3.3983978  3.3983978 ]]
#
#  [[1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]]]
# 25.976969478245298
# (array([0.1, 0.2, 0.3, 0.4]), array([1.07613881, 1.1200397 , 1.15908764, 1.19289247]), array([0.46184982, 0.41543619, 0.36487167, 0.31066147]))
# dF dpartial [array([2.93333151, 3.06497589, 3.18702424, 3.29660276]), 1] dimension_of_gradient_with_respect_to dfdp n_param 1
# n_param 1
# --------------------
# grad_envelope_list [[[2.93333151]
#   [3.06497589]
#   [3.18702424]
#   [3.29660276]]
#
#  [[1.        ]
#   [1.        ]
#   [1.        ]
#   [1.        ]]]
# (array([0.1, 0.2, 0.3, 0.4]), array([1.07613881, 1.1200397 , 1.15908764, 1.19289247]), array([0.46184982, 0.41543619, 0.36487167, 0.31066147]))
# dF dpartial [array([2.93333151, 3.06497589, 3.18702424, 3.29660276]), 1] dimension_of_gradient_with_respect_to dfdop n_param 2
# n_param 2
# --------------------
# grad_envelope_list [[[2.93333151 2.93333151]
#   [3.06497589 3.06497589]
#   [3.18702424 3.18702424]
#   [3.29660276 3.29660276]]
#
#  [[1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]]]
# 24.151331275403447
# (array([0.1, 0.2, 0.3, 0.4]), array([1.04683941, 1.09053704, 1.12954165, 1.16346352]), array([0.45902304, 0.41420121, 0.36524082, 0.31263107]))
# dF dpartial [array([2.8486335 , 2.9758718 , 3.09423793, 3.20100082]), 1] dimension_of_gradient_with_respect_to dfdp n_param 1
# n_param 1
# --------------------
# grad_envelope_list [[[2.8486335 ]
#   [2.9758718 ]
#   [3.09423793]
#   [3.20100082]]
#
#  [[1.        ]
#   [1.        ]
#   [1.        ]
#   [1.        ]]]
# (array([0.1, 0.2, 0.3, 0.4]), array([1.04683941, 1.09053704, 1.12954165, 1.16346352]), array([0.45902304, 0.41420121, 0.36524082, 0.31263107]))
# dF dpartial [array([2.8486335 , 2.9758718 , 3.09423793, 3.20100082]), 1] dimension_of_gradient_with_respect_to dfdop n_param 2
# n_param 2
# --------------------
# grad_envelope_list [[[2.8486335  2.8486335 ]
#   [2.9758718  2.9758718 ]
#   [3.09423793 3.09423793]
#   [3.20100082 3.20100082]]
#
#  [[1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]]]
# 22.494326056447143
# (array([0.1, 0.2, 0.3, 0.4]), array([1.01860689, 1.0620755 , 1.10100459, 1.13500519]), array([0.45597172, 0.41267597, 0.36525689, 0.31418828]))
# dF dpartial [array([2.76933408, 2.89236787, 3.00718549, 3.11118968]), 1] dimension_of_gradient_with_respect_to dfdp n_param 1
# n_param 1
# --------------------
# grad_envelope_list [[[2.76933408]
#   [2.89236787]
#   [3.00718549]
#   [3.11118968]]
#
#  [[1.        ]
#   [1.        ]
#   [1.        ]
#   [1.        ]]]
# (array([0.1, 0.2, 0.3, 0.4]), array([1.01860689, 1.0620755 , 1.10100459, 1.13500519]), array([0.45597172, 0.41267597, 0.36525689, 0.31418828]))
# dF dpartial [array([2.76933408, 2.89236787, 3.00718549, 3.11118968]), 1] dimension_of_gradient_with_respect_to dfdop n_param 2
# n_param 2
# --------------------
# grad_envelope_list [[[2.76933408 2.76933408]
#   [2.89236787 2.89236787]
#   [3.00718549 3.00718549]
#   [3.11118968 3.11118968]]
#
#  [[1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]]]
# 20.98836981630955
# (array([0.1, 0.2, 0.3, 0.4]), array([0.99141677, 1.0346336 , 1.07345811, 1.10750237]), array([0.45272507, 0.41089117, 0.36495179, 0.31536593]))
# dF dpartial [array([2.69505003, 2.81407497, 2.92547864, 3.02678914]), 1] dimension_of_gradient_with_respect_to dfdp n_param 1
# n_param 1
# --------------------
# grad_envelope_list [[[2.69505003]
#   [2.81407497]
#   [2.92547864]
#   [3.02678914]]
#
#  [[1.        ]
#   [1.        ]
#   [1.        ]
#   [1.        ]]]
# (array([0.1, 0.2, 0.3, 0.4]), array([0.99141677, 1.0346336 , 1.07345811, 1.10750237]), array([0.45272507, 0.41089117, 0.36495179, 0.31536593]))
# dF dpartial [array([2.69505003, 2.81407497, 2.92547864, 3.02678914]), 1] dimension_of_gradient_with_respect_to dfdop n_param 2
# n_param 2
# --------------------
# grad_envelope_list [[[2.69505003 2.69505003]
#   [2.81407497 2.81407497]
#   [2.92547864 2.92547864]
#   [3.02678914 3.02678914]]
#
#  [[1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]]]
# 19.617818201441803
# (array([0.1, 0.2, 0.3, 0.4]), array([0.96524236, 1.00818746, 1.04688129, 1.08093724]), array([0.44931033, 0.40887576, 0.36435585, 0.31619541]))
# dF dpartial [array([2.62542387, 2.740629  , 2.84875281, 2.9474407 ]), 1] dimension_of_gradient_with_respect_to dfdp n_param 1
# n_param 1
# --------------------
# grad_envelope_list [[[2.62542387]
#   [2.740629  ]
#   [2.84875281]
#   [2.9474407 ]]
#
#  [[1.        ]
#   [1.        ]
#   [1.        ]
#   [1.        ]]]
# (array([0.1, 0.2, 0.3, 0.4]), array([0.96524236, 1.00818746, 1.04688129, 1.08093724]), array([0.44931033, 0.40887576, 0.36435585, 0.31619541]))
# dF dpartial [array([2.62542387, 2.740629  , 2.84875281, 2.9474407 ]), 1] dimension_of_gradient_with_respect_to dfdop n_param 2
# n_param 2
# --------------------
# grad_envelope_list [[[2.62542387 2.62542387]
#   [2.740629   2.740629  ]
#   [2.84875281 2.84875281]
#   [2.9474407  2.9474407 ]]
#
#  [[1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]]]
# 18.368750153493828
# (array([0.1, 0.2, 0.3, 0.4]), array([0.94005514, 0.98271118, 1.02125102, 1.05528961]), array([0.44575277, 0.40665682, 0.36349769, 0.3167066 ]))
# dF dpartial [array([2.56012259, 2.67168986, 2.77666627, 2.87280702]), 1] dimension_of_gradient_with_respect_to dfdp n_param 1
# n_param 1
# --------------------
# grad_envelope_list [[[2.56012259]
#   [2.67168986]
#   [2.77666627]
#   [2.87280702]]
#
#  [[1.        ]
#   [1.        ]
#   [1.        ]
#   [1.        ]]]
# (array([0.1, 0.2, 0.3, 0.4]), array([0.94005514, 0.98271118, 1.02125102, 1.05528961]), array([0.44575277, 0.40665682, 0.36349769, 0.3167066 ]))
# dF dpartial [array([2.56012259, 2.67168986, 2.77666627, 2.87280702]), 1] dimension_of_gradient_with_respect_to dfdop n_param 2
# n_param 2
# --------------------
# grad_envelope_list [[[2.56012259 2.56012259]
#   [2.67168986 2.67168986]
#   [2.77666627 2.77666627]
#   [2.87280702 2.87280702]]
#
#  [[1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]]]
# 17.228774827226953
# (array([0.1, 0.2, 0.3, 0.4]), array([0.91582515, 0.95817721, 0.99654237, 1.03053731]), array([0.44207569, 0.40425955, 0.36240418, 0.31692779]))
# dF dpartial [array([2.49883632, 2.60694024, 2.70889926, 2.80257127]), 1] dimension_of_gradient_with_respect_to dfdp n_param 1
# n_param 1
# --------------------
# grad_envelope_list [[[2.49883632]
#   [2.60694024]
#   [2.70889926]
#   [2.80257127]]
#
#  [[1.        ]
#   [1.        ]
#   [1.        ]
#   [1.        ]]]
# (array([0.1, 0.2, 0.3, 0.4]), array([0.91582515, 0.95817721, 0.99654237, 1.03053731]), array([0.44207569, 0.40425955, 0.36240418, 0.31692779]))
# dF dpartial [array([2.49883632, 2.60694024, 2.70889926, 2.80257127]), 1] dimension_of_gradient_with_respect_to dfdop n_param 2
# n_param 2
# --------------------
# grad_envelope_list [[[2.49883632 2.49883632]
#   [2.60694024 2.60694024]
#   [2.70889926 2.70889926]
#   [2.80257127 2.80257127]]
#
#  [[1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]
#   [1.         1.        ]]]
# 16.186859477934693
# fit:   7%|▋         | 14/200 [01:35<21:13,  6.85s/it]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Program Files\Python310\lib\genericpath.py:30, in isfile(path)
#      29 try:
# ---> 30     st = os.stat(path)
#      31 except (OSError, ValueError):
#
# FileNotFoundError: [WinError 2] Das System kann die angegebene Datei nicht finden: 'C:\\Users\\jsl-rf\\.qiskit\\settings.conf'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 ode_regressor.fit(x_line, np.zeros((x_line.shape[0])),  weights=None)
#       2 f_QNN = ode_regressor.predict(x_line)
#
# File ~\Desktop\Qiskit\squlearnRF\src\squlearn\qnn\base_qnn.py:197, in BaseQNN.fit(self, X, y, weights)
#     195 self._param_op = self.param_op_ini.copy()
#     196 self._is_fitted = False
# --> 197 self._fit(X, y, weights)
#
# File ~\Desktop\Qiskit\squlearnRF\src\squlearn\qnn\qnnr.py:240, in QNNRegressor._fit(self, X, y, weights)
#     238 if self.callback == "pbar":
#     239     self._pbar = tqdm(total=self._total_iterations, desc="fit", file=sys.stdout)
# --> 240 self.partial_fit(X, y, weights)
#     241 if self.callback == "pbar":
#     242     self._pbar.close()
#
# File ~\Desktop\Qiskit\squlearnRF\src\squlearn\qnn\qnnr.py:209, in QNNRegressor.partial_fit(self, X, y, weights)
#     207 else:
#     208     if self.opt_param_op:
# --> 209         self._param, self._param_op = train(
#     210             self._qnn,
#     211             X,
#     212             y,
#     213             self._param,
#     214             self._param_op,
#     215             loss,
#     216             self.optimizer,
#     217             self.shot_control,
#     218             weights,
#     219             True,
#     220         )
#     221     else:
#     222         self._param = train(
#     223             self._qnn,
#     224             X,
#    (...)
#     232             False,
#     233         )
#
# File ~\Desktop\Qiskit\squlearnRF\src\squlearn\qnn\training.py:367, in train(qnn, input_values, ground_truth, param_ini, param_op_ini, loss, optimizer, shot_control, weights, opt_param_op)
#     364     else:
#     365         return np.array([])
# --> 367 result = optimizer.minimize(_fun, val_ini, _grad, bounds=None)
#     369 if hasattr(result, "x"):
#     370     result = result.x
#
# File ~\Desktop\Qiskit\squlearnRF\src\squlearn\optimizers\adam.py:129, in Adam.minimize(self, fun, x0, grad, bounds)
#     125     fval = fun(self.x)
#     127 # Calculate the gradient and average it over the last num_average gradients
#     128 # (1 is default: no averaging)
# --> 129 self.gradient_deque.append(grad(self.x))
#     130 gradient = np.average(self.gradient_deque, axis=0)
#     132 x_updated = self.step(x=self.x, grad=gradient)
#
# File ~\Desktop\Qiskit\squlearnRF\src\squlearn\qnn\training.py:347, in train.<locals>._grad(theta)
#     344         else:
#     345             raise ValueError("Loss variance necessary for ShotsFromRSTD shot control")
# --> 347 grad_values = qnn.evaluate(input_values, param_, param_op_, *loss.gradient_args_tuple)
#     348 grad = np.concatenate(
#     349     loss.gradient(
#     350         grad_values,
#    (...)
#     357     axis=None,
#     358 )
#     359 return grad
#
# File ~\Desktop\Qiskit\squlearnRF\src\squlearn\qnn\lowlevel_qnn_pennylane.py:389, in LowLevelQNNPennyLane.evaluate(self, x, param, param_obs, *values)
#     381 else:
#     382
#     383     # Direct evaluation of the QNN
#     384     if (todo_class.return_grad_x and todo_class.order > 1) or (
#     385         todo_class.order >= 1 and self._executor.shots is not None
#     386     ):  # TODO: Should be removed if PennyLane bug 4462 is fixed
#     387         # evaluate every single x, param, param_op combination separately
#     388         # faster evaluation for higher-order derivatives w.r.t. x
# --> 389         output = [
#     390             self._evaluate_todo_single_x(
#     391                 todo_class, x_inp_, param_inp_, param_obs_inp_
#     392             )
#     393             for x_inp_ in x_inp
#     394             for param_inp_ in param_inp
#     395             for param_obs_inp_ in param_obs_inp
#     396         ]
#     397         output = np.array(output)
#     399     else:
#     400         # evaluate only param, param_op combination separately and all x together
#     401         # Faster evaluation for lower-order derivatives
#
# File ~\Desktop\Qiskit\squlearnRF\src\squlearn\qnn\lowlevel_qnn_pennylane.py:390, in <listcomp>(.0)
#     381 else:
#     382
#     383     # Direct evaluation of the QNN
#     384     if (todo_class.return_grad_x and todo_class.order > 1) or (
#     385         todo_class.order >= 1 and self._executor.shots is not None
#     386     ):  # TODO: Should be removed if PennyLane bug 4462 is fixed
#     387         # evaluate every single x, param, param_op combination separately
#     388         # faster evaluation for higher-order derivatives w.r.t. x
#     389         output = [
# --> 390             self._evaluate_todo_single_x(
#     391                 todo_class, x_inp_, param_inp_, param_obs_inp_
#     392             )
#     393             for x_inp_ in x_inp
#     394             for param_inp_ in param_inp
#     395             for param_obs_inp_ in param_obs_inp
#     396         ]
#     397         output = np.array(output)
#     399     else:
#     400         # evaluate only param, param_op combination separately and all x together
#     401         # Faster evaluation for lower-order derivatives
#
# File ~\Desktop\Qiskit\squlearnRF\src\squlearn\qnn\lowlevel_qnn_pennylane.py:536, in LowLevelQNNPennyLane._evaluate_todo_single_x(self, todo_class, x, param, param_obs)
#     533     else:
#     534         deriv = qml.jacobian(deriv, argnum=arg_index)
# --> 536 hash_value = func.hash + str(todo_class.argnum)
#     537 deriv.hash = hash_value
#     538 value = self._executor.pennylane_execute(deriv, *(eval_tuple))
#
# File ~\Desktop\Qiskit\squlearnRF\src\squlearn\util\pennylane\pennylane_circuit.py:218, in PennyLaneCircuit.hash(self)
#     215 @property
#     216 def hash(self) -> str:
#     217     """Hashable object of the circuit and observable for caching"""
# --> 218     return str(self._qiskit_circuit) + str(self._qiskit_observable)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\qiskit\circuit\quantumcircuit.py:491, in QuantumCircuit.__str__(self)
#     490 def __str__(self) -> str:
# --> 491     return str(self.draw(output="text"))
#
# File ~\AppData\Roaming\Python\Python310\site-packages\qiskit\circuit\quantumcircuit.py:1807, in QuantumCircuit.draw(self, output, scale, filename, style, interactive, plot_barriers, reverse_bits, justify, vertical_compression, idle_wires, with_layout, fold, ax, initial_state, cregbundle, wire_order, expr_len)
#    1804 # pylint: disable=cyclic-import
#    1805 from qiskit.visualization import circuit_drawer
# -> 1807 return circuit_drawer(
#    1808     self,
#    1809     scale=scale,
#    1810     filename=filename,
#    1811     style=style,
#    1812     output=output,
#    1813     interactive=interactive,
#    1814     plot_barriers=plot_barriers,
#    1815     reverse_bits=reverse_bits,
#    1816     justify=justify,
#    1817     vertical_compression=vertical_compression,
#    1818     idle_wires=idle_wires,
#    1819     with_layout=with_layout,
#    1820     fold=fold,
#    1821     ax=ax,
#    1822     initial_state=initial_state,
#    1823     cregbundle=cregbundle,
#    1824     wire_order=wire_order,
#    1825     expr_len=expr_len,
#    1826 )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\qiskit\visualization\circuit\circuit_visualization.py:197, in circuit_drawer(circuit, scale, filename, style, output, interactive, plot_barriers, reverse_bits, justify, vertical_compression, idle_wires, with_layout, fold, ax, initial_state, cregbundle, wire_order, expr_len)
#     195 image = None
#     196 expr_len = max(expr_len, 0)
# --> 197 config = user_config.get_config()
#     198 # Get default from config file else use text
#     199 default_output = "text"
#
# File ~\AppData\Roaming\Python\Python310\site-packages\qiskit\user_config.py:235, in get_config()
#     225 """Read the config file from the default location or env var
#     226
#     227 It will read a config file at either the default location
#    (...)
#     232     dict: The settings dict from the parsed config file.
#     233 """
#     234 filename = os.getenv("QISKIT_SETTINGS", DEFAULT_FILENAME)
# --> 235 if not os.path.isfile(filename):
#     236     return {}
#     237 user_config = UserConfig(filename)
#
# File c:\Program Files\Python310\lib\genericpath.py:30, in isfile(path)
#      28 """Test whether a path is a regular file"""
#      29 try:
# ---> 30     st = os.stat(path)
#      31 except (OSError, ValueError):
#      32     return False
#
# KeyboardInterrupt:

# %%
plt.plot(f_QNN)
plt.plot(f_exact)
